# %%
import os
import re
import subprocess
import glob
import random
import whisper
import csv
from pydub import AudioSegment
from pydub.silence import split_on_silence

# %% [markdown]
# ## Cropping and Extracting Audio-Script

# %%
# --- 1. SETUP ---
cha_file = "/rds/general/user/ak8224/home/emoji_project/data/ASD/02_T1_1.cha"
video_file = "/rds/general/user/ak8224/home/emoji_project/data/ASD/02_T1_1.mp4"
output_dir = "/rds/general/user/ak8224/home/emoji_project/data/ASD/1"

os.makedirs(output_dir, exist_ok=True)

# --- 2. REGEX PATTERNS ---
# This strictly looks for the timestamp bullets: 1917578_1923343
timestamp_pattern = re.compile(r"(\d+)_(\d+)")

clip_count = 0
print(f"🎧 Scanning {cha_file} and extracting 22050Hz audio...")

# --- 3. PARSING & EXTRACTION ---
with open(cha_file, "r", encoding="utf-8") as f:
    for line in f:
        # ONLY look at the Patient's lines
        if line.startswith("*CHI:"):
            match = timestamp_pattern.search(line)
            
            if match:
                start_ms = int(match.group(1))
                end_ms = int(match.group(2))
                
                # Convert to seconds
                start_sec = start_ms / 1000.0
                duration_sec = (end_ms - start_ms) / 1000.0
                
                # --- CLEAN THE TRANSCRIPT ---
                # Remove the '*CHI:' prefix and the timestamp bullet to isolate the text
                clean_text = line.replace("*CHI:", "").split("")[0].strip()
                
                # Skip completely empty lines just in case
                if not clean_text:
                    continue

                # --- 4. FILE PATHS ---
                base_filename = f"patient1_{clip_count:04d}"
                out_wav = os.path.join(output_dir, f"{base_filename}.wav")
                out_txt = os.path.join(output_dir, f"{base_filename}.txt")
                
                # --- 5. SAVE THE TRANSCRIPT ---
                with open(out_txt, "w", encoding="utf-8") as txt_file:
                    txt_file.write(clean_text)
                
                # --- 6. CROP & CONVERT AUDIO WITH FFMPEG ---
                cmd = [
                    "ffmpeg", "-y", 
                    "-ss", str(start_sec), 
                    "-i", video_file, 
                    "-t", str(duration_sec),
                    "-ar", "22050",          # Resample directly to 22050 Hz
                    "-ac", "1",              # Convert to Mono audio
                    "-c:a", "pcm_s16le",     # Uncompressed 16-bit WAV format
                    "-vn",                   # Strip the video track completely
                    out_wav
                ]
                
                # Run FFmpeg silently
                subprocess.run(cmd, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
                
                clip_count += 1

print(f"\n✅ Done! Extracted {clip_count} audio files and transcripts to the '{output_dir}' folder.")
# Out:
# 🎧 Scanning /rds/general/user/ak8224/home/emoji_project/data/ASD/02_T1_1.cha and extracting 22050Hz audio...
#
# ✅ Done! Extracted 40 audio files and transcripts to the '/rds/general/user/ak8224/home/emoji_project/data/ASD/1' folder.

# %%
# --- 1. SETUP ---
cha_file = "/rds/general/user/ak8224/home/emoji_project/data/ASD/02_T1_2.cha"
video_file = "/rds/general/user/ak8224/home/emoji_project/data/ASD/02_T1_2.mp4"
output_dir = "/rds/general/user/ak8224/home/emoji_project/data/ASD/2"

os.makedirs(output_dir, exist_ok=True)

# --- 2. REGEX PATTERNS ---
# This strictly looks for the timestamp bullets: 1917578_1923343
timestamp_pattern = re.compile(r"(\d+)_(\d+)")

clip_count = 0
print(f"🎧 Scanning {cha_file} and extracting 22050Hz audio...")

# --- 3. PARSING & EXTRACTION ---
with open(cha_file, "r", encoding="utf-8") as f:
    for line in f:
        # ONLY look at the Patient's lines
        if line.startswith("*CHI:"):
            match = timestamp_pattern.search(line)
            
            if match:
                start_ms = int(match.group(1))
                end_ms = int(match.group(2))
                
                # Convert to seconds
                start_sec = start_ms / 1000.0
                duration_sec = (end_ms - start_ms) / 1000.0
                
                # --- CLEAN THE TRANSCRIPT ---
                # Remove the '*CHI:' prefix and the timestamp bullet to isolate the text
                clean_text = line.replace("*CHI:", "").split("")[0].strip()
                
                # Skip completely empty lines just in case
                if not clean_text:
                    continue

                # --- 4. FILE PATHS ---
                base_filename = f"patient2_{clip_count:04d}"
                out_wav = os.path.join(output_dir, f"{base_filename}.wav")
                out_txt = os.path.join(output_dir, f"{base_filename}.txt")
                
                # --- 5. SAVE THE TRANSCRIPT ---
                with open(out_txt, "w", encoding="utf-8") as txt_file:
                    txt_file.write(clean_text)
                
                # --- 6. CROP & CONVERT AUDIO WITH FFMPEG ---
                cmd = [
                    "ffmpeg", "-y", 
                    "-ss", str(start_sec), 
                    "-i", video_file, 
                    "-t", str(duration_sec),
                    "-ar", "22050",          # Resample directly to 22050 Hz
                    "-ac", "1",              # Convert to Mono audio
                    "-c:a", "pcm_s16le",     # Uncompressed 16-bit WAV format
                    "-vn",                   # Strip the video track completely
                    out_wav
                ]
                
                # Run FFmpeg silently
                subprocess.run(cmd, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
                
                clip_count += 1

print(f"\n✅ Done! Extracted {clip_count} audio files and transcripts to the '{output_dir}' folder.")
# Out:
# 🎧 Scanning /rds/general/user/ak8224/home/emoji_project/data/ASD/02_T1_2.cha and extracting 22050Hz audio...
#
# ✅ Done! Extracted 86 audio files and transcripts to the '/rds/general/user/ak8224/home/emoji_project/data/ASD/2' folder.

# %%
# --- 1. SETUP ---
cha_file = "/rds/general/user/ak8224/home/emoji_project/data/ASD/02_T3_1.cha"
video_file = "/rds/general/user/ak8224/home/emoji_project/data/ASD/02_T3_1.mp4"
output_dir = "/rds/general/user/ak8224/home/emoji_project/data/ASD/3"

os.makedirs(output_dir, exist_ok=True)

# --- 2. REGEX PATTERNS ---
# This strictly looks for the timestamp bullets: 1917578_1923343
timestamp_pattern = re.compile(r"(\d+)_(\d+)")

clip_count = 0
print(f"🎧 Scanning {cha_file} and extracting 22050Hz audio...")

# --- 3. PARSING & EXTRACTION ---
with open(cha_file, "r", encoding="utf-8") as f:
    for line in f:
        # ONLY look at the Patient's lines
        if line.startswith("*CHI:"):
            match = timestamp_pattern.search(line)
            
            if match:
                start_ms = int(match.group(1))
                end_ms = int(match.group(2))
                
                # Convert to seconds
                start_sec = start_ms / 1000.0
                duration_sec = (end_ms - start_ms) / 1000.0
                
                # --- CLEAN THE TRANSCRIPT ---
                # Remove the '*CHI:' prefix and the timestamp bullet to isolate the text
                clean_text = line.replace("*CHI:", "").split("")[0].strip()
                
                # Skip completely empty lines just in case
                if not clean_text:
                    continue

                # --- 4. FILE PATHS ---
                base_filename = f"patient3_{clip_count:04d}"
                out_wav = os.path.join(output_dir, f"{base_filename}.wav")
                out_txt = os.path.join(output_dir, f"{base_filename}.txt")
                
                # --- 5. SAVE THE TRANSCRIPT ---
                with open(out_txt, "w", encoding="utf-8") as txt_file:
                    txt_file.write(clean_text)
                
                # --- 6. CROP & CONVERT AUDIO WITH FFMPEG ---
                cmd = [
                    "ffmpeg", "-y", 
                    "-ss", str(start_sec), 
                    "-i", video_file, 
                    "-t", str(duration_sec),
                    "-ar", "22050",          # Resample directly to 22050 Hz
                    "-ac", "1",              # Convert to Mono audio
                    "-c:a", "pcm_s16le",     # Uncompressed 16-bit WAV format
                    "-vn",                   # Strip the video track completely
                    out_wav
                ]
                
                # Run FFmpeg silently
                subprocess.run(cmd, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
                
                clip_count += 1

print(f"\n✅ Done! Extracted {clip_count} audio files and transcripts to the '{output_dir}' folder.")
# Out:
# 🎧 Scanning /rds/general/user/ak8224/home/emoji_project/data/ASD/02_T3_1.cha and extracting 22050Hz audio...
#
# ✅ Done! Extracted 39 audio files and transcripts to the '/rds/general/user/ak8224/home/emoji_project/data/ASD/3' folder.

# %%
# --- 1. SETUP ---
cha_file = "/rds/general/user/ak8224/home/emoji_project/data/ASD/02_T3_2.cha"
video_file = "/rds/general/user/ak8224/home/emoji_project/data/ASD/02_T3_2.mp4"
output_dir = "/rds/general/user/ak8224/home/emoji_project/data/ASD/4"

os.makedirs(output_dir, exist_ok=True)

# --- 2. REGEX PATTERNS ---
# This strictly looks for the timestamp bullets: 1917578_1923343
timestamp_pattern = re.compile(r"(\d+)_(\d+)")

clip_count = 0
print(f"🎧 Scanning {cha_file} and extracting 22050Hz audio...")

# --- 3. PARSING & EXTRACTION ---
with open(cha_file, "r", encoding="utf-8") as f:
    for line in f:
        # ONLY look at the Patient's lines
        if line.startswith("*CHI:"):
            match = timestamp_pattern.search(line)
            
            if match:
                start_ms = int(match.group(1))
                end_ms = int(match.group(2))
                
                # Convert to seconds
                start_sec = start_ms / 1000.0
                duration_sec = (end_ms - start_ms) / 1000.0
                
                # --- CLEAN THE TRANSCRIPT ---
                # Remove the '*CHI:' prefix and the timestamp bullet to isolate the text
                clean_text = line.replace("*CHI:", "").split("")[0].strip()
                
                # Skip completely empty lines just in case
                if not clean_text:
                    continue

                # --- 4. FILE PATHS ---
                base_filename = f"patient4_{clip_count:04d}"
                out_wav = os.path.join(output_dir, f"{base_filename}.wav")
                out_txt = os.path.join(output_dir, f"{base_filename}.txt")
                
                # --- 5. SAVE THE TRANSCRIPT ---
                with open(out_txt, "w", encoding="utf-8") as txt_file:
                    txt_file.write(clean_text)
                
                # --- 6. CROP & CONVERT AUDIO WITH FFMPEG ---
                cmd = [
                    "ffmpeg", "-y", 
                    "-ss", str(start_sec), 
                    "-i", video_file, 
                    "-t", str(duration_sec),
                    "-ar", "22050",          # Resample directly to 22050 Hz
                    "-ac", "1",              # Convert to Mono audio
                    "-c:a", "pcm_s16le",     # Uncompressed 16-bit WAV format
                    "-vn",                   # Strip the video track completely
                    out_wav
                ]
                
                # Run FFmpeg silently
                subprocess.run(cmd, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
                
                clip_count += 1

print(f"\n✅ Done! Extracted {clip_count} audio files and transcripts to the '{output_dir}' folder.")
# Out:
# 🎧 Scanning /rds/general/user/ak8224/home/emoji_project/data/ASD/02_T3_2.cha and extracting 22050Hz audio...
#
# ✅ Done! Extracted 14 audio files and transcripts to the '/rds/general/user/ak8224/home/emoji_project/data/ASD/4' folder.

# %% [markdown]
# ## Pre-Process Script

# %%
def clean_aphasia_transcript(text):
    """
    Strips out AphasiaBank CHAT formatting but keeps the raw spoken words.
    """
    # 1. Strip out the patient/other/interviewer label if it accidentally got left in
    text = text.replace("*PAR:", "")
    text = re.sub(r'&\*[A-Z]+:', '', text)
    
    # 2. Strip out timestamp bullets (e.g., 14328_26169)
    text = re.sub(r'\d+_\d+', '', text)
    
    # 3. Target the prefixes (&- and &+) but KEEP the attached filler words
    # Converts "&-um" to "um" and "&+i" to "i"
    text = re.sub(r'&[-+]', '', text)
    
    # 4. Remove all bracketed syntax (like [/], [//], or [* m:0s])
    text = re.sub(r'\[.*?\]', '', text)
    
    # 5. Remove angle brackets < and > used for grouping phrases
    text = re.sub(r'[<>]', '', text)
    
    # 6. Remove CHAT pause markers like (.), (..), (...) 
    text = re.sub(r'\(\.{1,3}\)', '', text)
    
    # 7. Clean up any weird double spaces left behind by the deleted symbols
    text = re.sub(r'\s+', ' ', text)
    
    return text.strip()

# %%
# --- BATCH PROCESS DIRECTORY ---
dataset_dir = "/rds/general/user/ak8224/home/emoji_project/data/ASD/script"
txt_files = glob.glob(f"{dataset_dir}/*.txt")

print(f"🧹 Found {len(txt_files)} transcripts to clean. Starting...")

for file_path in txt_files:
    with open(file_path, "r", encoding="utf-8") as f:
        raw_text = f.read()
        
    cleaned_text = clean_aphasia_transcript(raw_text)
    
    with open(file_path, "w", encoding="utf-8") as f:
        f.write(cleaned_text)

print("✅ All transcripts successfully sanitized!")
# Out:
# 🧹 Found 179 transcripts to clean. Starting...
# ✅ All transcripts successfully sanitized!

# %% [markdown]
# ## Pre-Process Audio

# %%
def preprocess_aphasia_audio(input_dir):
    """
    Normalizes volume to -23 dBFS and perfectly crops long silences down to 1 second.
    """
    output_dir = os.path.join(input_dir, "preprocessed")
    os.makedirs(output_dir, exist_ok=True)

    # Grab all your handpicked wav files
    wav_files = glob.glob(os.path.join(input_dir, "*.wav"))
    print(f"🎧 Found {len(wav_files)} files. Starting normalization and silence cropping...\n")

    for file_path in wav_files:
        filename = os.path.basename(file_path)
        out_path = os.path.join(output_dir, filename)

        # --- 1. LOAD AUDIO ---
        audio = AudioSegment.from_wav(file_path)
        original_duration = len(audio) / 1000.0

        # --- 2. VOLUME NORMALIZATION ---
        # We target -23 dBFS, which acts as a fantastic LUFS equivalent for mono voice tracks
        target_dBFS = -23.0
        gain_change = target_dBFS - audio.dBFS
        normalized_audio = audio.apply_gain(gain_change)

        # --- 3. DETECT & CROP SILENCE ---
        # min_silence_len=1000: We only trigger on silences longer than 1 second
        # silence_thresh=-40: Anything quieter than -40 dBFS is considered "dead air"
        # keep_silence=250: This is the magic trick. It leaves a 250ms "buffer" of room tone 
        # on the edges of the spoken words so we don't accidentally chop off natural breath sounds.
        chunks = split_on_silence(
            normalized_audio,
            min_silence_len=1000,
            silence_thresh=-40,
            keep_silence=250 
        )

        # --- 4. RE-STITCH WITH 1 SECOND GAP ---
        if chunks:
            final_audio = chunks[0]
            
            # Since we kept 250ms of breath on the tail of Chunk A and 250ms on the head of Chunk B,
            # we inject exactly 500ms of pure silence between them to equal a perfect 1.0 second pause.
            one_sec_gap = AudioSegment.silent(duration=500)

            for chunk in chunks[1:]:
                final_audio += one_sec_gap + chunk
        else:
            # Fallback in case a file has zero pauses longer than 1 second
            final_audio = normalized_audio

        new_duration = len(final_audio) / 1000.0
        time_saved = original_duration - new_duration

        # --- 5. EXPORT FOR TTS ---
        # Enforce the strict 22050 Hz Mono requirement during export
        final_audio.export(out_path, format="wav", parameters=["-ar", "22050", "-ac", "1"])

        # --- LOGGING ---
        if time_saved > 0.1:
            print(f"✂️ {filename}: Reduced from {original_duration:.1f}s to {new_duration:.1f}s (Trimmed {time_saved:.1f}s of dead air)")
        else:
            print(f"✅ {filename}: Processed (No long silences detected)")

    print(f"\n🎉 All preprocessed audio successfully saved to: {output_dir}")

# %%
# Point this to the folder where your 100 handpicked files live
preprocess_aphasia_audio("/rds/general/user/ak8224/home/emoji_project/data/ASD/final")
# Out:
# 🎧 Found 77 files. Starting normalization and silence cropping...
#
# ✅ patient2_0018.wav: Processed (No long silences detected)
# ✅ patient3_0017.wav: Processed (No long silences detected)
# ✅ patient3_0026.wav: Processed (No long silences detected)
# ✅ patient2_0008.wav: Processed (No long silences detected)
# ✅ patient3_0016.wav: Processed (No long silences detected)
# ✅ patient2_0081.wav: Processed (No long silences detected)
# ✅ patient2_0050.wav: Processed (No long silences detected)
# ✅ patient4_0008.wav: Processed (No long silences detected)
# ✅ patient2_0052.wav: Processed (No long silences detected)
# ✅ patient1_0037.wav: Processed (No long silences detected)
# ✅ patient2_0034.wav: Processed (No long silences detected)
# ✅ patient3_0037.wav: Processed (No long silences detected)
# ✅ patient2_0030.wav: Processed (No long silences detected)
# ✅ patient4_0001.wav: Processed (No long silences detected)
# ✅ patient3_0025.wav: Processed (No long silences detected)
# ✅ patient3_0005.wav: Processed (No long silences detected)
# ✅ patient3_0010.wav: Processed (No long silences detected)
# ✅ patient2_0082.wav: Processed (No long silences detected)
# ✅ patient2_0010.wav: Processed (No long silences detected)
# ✅ patient3_0031.wav: Processed (No long silences detected)
# ✅ patient3_0008.wav: Processed (No long silences detected)
# ✅ patient2_0048.wav: Processed (No long silences detected)
# ✅ patient4_0000.wav: Processed (No long silences detected)
# ✅ patient2_0016.wav: Processed (No long silences detected)
# ✅ patient3_0015.wav: Processed (No long silences detected)
# ✅ patient3_0019.wav: Processed (No long silences detected)
# ✅ patient2_0066.wav: Processed (No long silences detected)
# ✅ patient2_0073.wav: Processed (No long silences detected)
# ✅ patient1_0038.wav: Processed (No long silences detected)
# ✅ patient3_0022.wav: Processed (No long silences detected)
# ✅ patient2_0063.wav: Processed (No long silences detected)
# ✅ patient3_0002.wav: Processed (No long silences detected)
# ✅ patient3_0020.wav: Processed (No long silences detected)
# ✅ patient3_0006.wav: Processed (No long silences detected)
# ✂️ patient3_0014.wav: Reduced from 1.9s to 1.2s (Trimmed 0.8s of dead air)
# ✅ patient3_0038.wav: Processed (No long silences detected)
# ✅ patient4_0011.wav: Processed (No long silences detected)
# ✅ patient3_0003.wav: Processed (No long silences detected)
# ✅ patient3_0004.wav: Processed (No long silences detected)
# ✅ patient2_0078.wav: Processed (No long silences detected)
# ✅ patient2_0036.wav: Processed (No long silences detected)
# ✅ patient2_0019.wav: Processed (No long silences detected)
# ✅ patient2_0080.wav: Processed (No long silences detected)
# ✅ patient3_0012.wav: Processed (No long silences detected)
# ✅ patient3_0034.wav: Processed (No long silences detected)
# ✅ patient3_0021.wav: Processed (No long silences detected)
# ✅ patient4_0004.wav: Processed (No long silences detected)
# ✅ patient3_0013.wav: Processed (No long silences detected)
# ✅ patient4_0007.wav: Processed (No long silences detected)
# ✅ patient1_0039.wav: Processed (No long silences detected)
# ✅ patient2_0032.wav: Processed (No long silences detected)
# ✅ patient2_0049.wav: Processed (No long silences detected)
# ✅ patient2_0072.wav: Processed (No long silences detected)
# ✅ patient1_0016.wav: Processed (No long silences detected)
# ✅ patient3_0028.wav: Processed (No long silences detected)
# ✅ patient2_0051.wav: Processed (No long silences detected)
# ✅ patient2_0060.wav: Processed (No long silences detected)
# ✅ patient3_0027.wav: Processed (No long silences detected)
# ✅ patient2_0031.wav: Processed (No long silences detected)
# ✅ patient2_0015.wav: Processed (No long silences detected)
# ✅ patient2_0043.wav: Processed (No long silences detected)
# ✅ patient2_0055.wav: Processed (No long silences detected)
# ✅ patient3_0036.wav: Processed (No long silences detected)
# ✅ patient2_0012.wav: Processed (No long silences detected)
# ✅ patient3_0001.wav: Processed (No long silences detected)
# ✅ patient3_0009.wav: Processed (No long silences detected)
# ✅ patient3_0018.wav: Processed (No long silences detected)
# ✅ patient2_0029.wav: Processed (No long silences detected)
# ✅ patient2_0044.wav: Processed (No long silences detected)
# ✅ patient2_0041.wav: Processed (No long silences detected)
# ✅ patient3_0011.wav: Processed (No long silences detected)
# ✅ patient2_0024.wav: Processed (No long silences detected)
# ✅ patient3_0030.wav: Processed (No long silences detected)
# ✅ patient3_0029.wav: Processed (No long silences detected)
# ✅ patient3_0007.wav: Processed (No long silences detected)
# ✅ patient2_0028.wav: Processed (No long silences detected)
# ✅ patient3_0035.wav: Processed (No long silences detected)
#
# 🎉 All preprocessed audio successfully saved to: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed

# %% [markdown]
# ## Create Final Metadata (LJSpeech Format)

# %%
# --- 1. SETUP PATHS ---
hpc_root = "/rds/general/user/ak8224/home"

# Directory containing your final 100 preprocessed audio files
wavs_dir = f"{hpc_root}/emoji_project/data/ASD/final/preprocessed"

# Directory containing your cleaned text scripts
scripts_dir = f"{hpc_root}/emoji_project/data/ASD/script"

# Where to save the final metadata file
output_metadata = f"{hpc_root}/emoji_project/data/ASD/final/preprocessed/metadata.csv"

# --- 2. GATHER AUDIO FILES ---
wav_files = glob.glob(os.path.join(wavs_dir, "*.wav"))
print(f"🔍 Found {len(wav_files)} audio files in the preprocessed directory.")

metadata_lines = []
missing_scripts = 0

# --- 3. MATCH AND BUILD ---
for wav_path in wav_files:
    # Extract just the filename without the .wav extension (e.g., "patient_0001")
    base_name = os.path.splitext(os.path.basename(wav_path))[0]
    
    # Build the path to where the matching text file *should* be
    txt_path = os.path.join(scripts_dir, f"{base_name}.txt")
    
    # Check if the text file actually exists in the script directory
    if os.path.exists(txt_path):
        with open(txt_path, "r", encoding="utf-8") as f:
            # Read the transcript and strip any accidental whitespace/newlines
            transcript = f.read().strip()
            
        # Format: <absolute_wav_path>|<speaker_id>|<transcript>
        line = f"{wav_path}|2|{transcript}"
        metadata_lines.append(line)
    else:
        print(f"⚠️ Warning: Could not find matching transcript for {base_name}.wav")
        missing_scripts += 1

# --- 4. SAVE TO CSV ---
with open(output_metadata, "w", encoding="utf-8") as f:
    for line in metadata_lines:
        f.write(line + "\n")

# --- 5. REPORTING ---
print(f"\n✅ Successfully generated metadata.csv with {len(metadata_lines)} entries!")
if missing_scripts > 0:
    print(f"ℹ️ Skipped {missing_scripts} audio files because their text files were missing.")
print(f"📄 Saved to: {output_metadata}")
# Out:
# 🔍 Found 77 audio files in the preprocessed directory.
#
# ✅ Successfully generated metadata.csv with 77 entries!
# 📄 Saved to: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/metadata.csv

# %% [markdown]
# ## Create Split for Fine-Tuning

# %%
metadata_path = "/rds/general/user/ak8224/home/MedEmoji-TTS/data/asd/metadata.csv"

with open(metadata_path, 'r') as f:
    lines = [line.strip() for line in f.readlines()]

random.shuffle(lines)

split_idx = int(len(lines) * 0.95)
train_lines = lines[:split_idx]
val_lines = lines[split_idx:]

with open("/rds/general/user/ak8224/home/MedEmoji-TTS/data/asd/train.txt", "w") as f:
    f.write("\n".join(train_lines) + "\n")

with open("/rds/general/user/ak8224/home/MedEmoji-TTS/data/asd/val.txt", "w") as f:
    f.write("\n".join(val_lines) + "\n")

print(f"✅ Created train.txt ({len(train_lines)} files) and val.txt ({len(val_lines)} files)!")
# Out:
# ✅ Created train.txt (73 files) and val.txt (4 files)!

# %% [markdown]
# ## Improving Script Punctuation

# %%
print("Loading Whisper model...")
model = whisper.load_model("small")

def process_metadata(input_csv, output_csv):
    # Open the input and create a new output file
    with open(input_csv, 'r', encoding='utf-8') as infile, \
         open(output_csv, 'w', encoding='utf-8', newline='') as outfile:
        
        # We use the pipe '|' delimiter based on your Matcha-TTS format
        reader = csv.reader(infile, delimiter='|')
        writer = csv.writer(outfile, delimiter='|')
        
        for row in reader:
            if len(row) < 3:
                continue
                
            audio_path = row[0].strip()
            speaker_id = row[1].strip()
            original_script = row[2].strip()
            
            print(f"\n🎧 Processing: {audio_path}")
            
            if not os.path.exists(audio_path):
                print(f"⚠️ Audio file not found, skipping...")
                continue
            
            # 2. Extract words and exact millisecond timestamps
            result = model.transcribe(audio_path, word_timestamps=True)
            
            new_script = []
            words = []
            
            # Flatten the Whisper segments into a single list of words
            for segment in result['segments']:
                for word in segment['words']:
                    words.append(word)
            
            # 3. Calculate gaps and apply your punctuation rules!
            for i in range(len(words)):
                current_word = words[i]['word'].strip()
                new_script.append(current_word)
                
                # Check the gap between this word and the next word
                if i < len(words) - 1:
                    next_word = words[i+1]
                    gap = next_word['start'] - words[i]['end']
                    
                    # Apply the rules we discussed
                    if gap >= 1.0:
                        new_script.append(".")
                    elif gap >= 0.5:
                        new_script.append("...")
                    elif gap >= 0.25: # 0.25s is a good baseline for a short comma pause
                        new_script.append(",")
                        
            # 4. Clean up the formatting
            # Whisper outputs raw words, so we join them and fix the punctuation spacing
            final_text = " ".join(new_script).replace(" .", ".").replace(" ,", ",").replace(" ...", "...")
            
            # Write the beautifully aligned row to the new file
            writer.writerow([audio_path, speaker_id, final_text])
            
            print(f"📖 Original: {original_script}")
            print(f"✨ Aligned:  {final_text}")
# Out:
# Loading Whisper model...

# %%
INPUT_FILE = "/rds/general/user/ak8224/home/MedEmoji-TTS/data/asd/metadata.csv"
OUTPUT_FILE = "/rds/general/user/ak8224/home/MedEmoji-TTS/data/asd/metadata_aligned.csv"
    
process_metadata(INPUT_FILE, OUTPUT_FILE)
print("\n✅ Alignment complete! You can now use metadata_aligned.csv for training.")
# Out:
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0018.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: what is the weather ?
# ✨ Aligned:  Empress 2021
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0017.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" we must be quiet so everyone can hear .
# ✨ Aligned:  We must be quiet still and we don't change anything.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0026.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" George loved elephants .
# ✨ Aligned:  Schools andいул white.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0008.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: what ?
# ✨ Aligned:  What?
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0016.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" the librarian put the finger to her wips .
# ✨ Aligned:  forHow grandpa how washing劉velly... lipstick
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0081.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: is it itchy ?
# ✨ Aligned:  This is it.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0050.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: one .
# ✨ Aligned:  one.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient4_0008.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: ha .
# ✨ Aligned:  Oh
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0052.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: one , two .
# ✨ Aligned:  One, two.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient1_0037.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: Windows_Ten ?
# ✨ Aligned:  Repeat once again.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0034.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: where's Daddy ?
# ✨ Aligned:  We study!
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0037.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" George had found a special cart for carry books .
# ✨ Aligned:  George has found a special cause for the carry.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0030.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: Mister Chad .
# ✨ Aligned:  Mix it up, chat.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient4_0001.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: &=gasps .
# ✨ Aligned:  icking
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0025.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" and here was the book about elephants .
# ✨ Aligned:  And here's what's the book about Ellen.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0005.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" he had never seen so many books before either .
# ✨ Aligned:  He has never seen so many books before either.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0010.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" he sat down with a ↫g↫group of children to listen .
# ✨ Aligned:  Old Chinese Chinese
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0082.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: is it ?
# ✨ Aligned:  Is it?
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0010.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: can you show it to me ?
# ✨ Aligned:  You shall see me.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0031.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" squeak went the shelf .
# ✨ Aligned:  it's weak... but it's good show
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0008.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" it was sowi hour .
# ✨ Aligned:  It was bookstore.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0048.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: black .
# ✨ Aligned:  Black.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient4_0000.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: want to .
# ✨ Aligned:  One, two...
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0016.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: what is bits ?
# ✨ Aligned:  Spits
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0015.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: shout a girl +".
# ✨ Aligned:  Stay,, transform, you fabricator!
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0019.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" but it's the monkey .
# ✨ Aligned:  Bye, it's your monkey!
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0066.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: banane@s:fra .
# ✨ Aligned:  Günaydın!
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0073.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: am I sleepy ?
# ✨ Aligned:  Heard him speaking.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient1_0038.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: I'm asking you .
# ✨ Aligned:  I scared you!
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0022.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" mm mm .
# ✨ Aligned:  Mm -hmm.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0063.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: French .
# ✨ Aligned:  Switch.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0002.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" he has a good little monkey and always very curious .
# ✨ Aligned:  But he has a good way of monkey and always play with children.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0020.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: said the boy +".
# ✨ Aligned:  Set it aboard.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0006.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: CHILDNAME .
# ✨ Aligned:  K -BUN
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0014.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" look a monkey .
# ✨ Aligned:  We're the monkeys!
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0038.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" xxx now George could carry all the books he wanted .
# ✨ Aligned:  Why not rock?... Now George couldn't carry all the books he went.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient4_0011.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: ha ha ha ha ha ha .
# ✨ Aligned:
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0003.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: today George and his friend ma man with the yellow hat were at the wibrary .
# ✨ Aligned:  choice and this way my man with a yellow hat will add a wide weight.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0004.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" George had never between mm to &~ba &=burps &~befu a library before .
# ✨ Aligned:  wrest lers ි න ් ඇ ව න h kal ප ි ර ර ට 风 ල ් ව න ් ම ි න ් ව න ් ව ව
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0078.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: I bump this hat .
# ✨ Aligned:  So bump this hat.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0036.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: in the office .
# ✨ Aligned:  In implicit!
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0019.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: is it sunny or rainy ?
# ✨ Aligned:  Is it sunny or rainy?
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0080.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: mosquito bite .
# ✨ Aligned:  goodbye
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0012.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" he had to see the dinosaur book .
# ✨ Aligned:  to see the dinosaur book.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0034.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" squeak xxx again .
# ✨ Aligned:  I grade it as sweet by a little bit so一點.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0021.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" the library nod and smell .
# ✨ Aligned:  That was a nice man.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient4_0004.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: &=mumbles .
# ✨ Aligned:  I need my w battleship
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0013.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" he tiptoed closer .
# ✨ Aligned:  Eat it all close.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient4_0007.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: da .
# ✨ Aligned:  Aw.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient1_0039.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: good .
# ✨ Aligned:  Good!
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0032.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: where is Daddy ?
# ✨ Aligned:  Where is daddy?
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0049.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: nose .
# ✨ Aligned:  No!
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0072.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: are you sleepy ?
# ✨ Aligned:  I'm sleepy.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient1_0016.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: Mister Chad .
# ✨ Aligned:  because I had
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0028.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" George found so many good books .
# ✨ Aligned:  George Brown,, so many good...
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0051.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: one , two .
# ✨ Aligned:  One, two.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0060.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: &=hums .
# ✨ Aligned:  I'm a baby,... baby
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0027.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" he added to a his piles .
# ✨ Aligned:  Next,, he added to his bio.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0031.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: French .
# ✨ Aligned:  RUNCH!
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0015.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: ou .
# ✨ Aligned:  안녕
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0043.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: music .
# ✨ Aligned:  you
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0055.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: okay .
# ✨ Aligned:  Okay.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0036.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" xxx after all .
# ✨ Aligned:  Why is the weapon in the show?
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0012.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: is it radio ?
# ✨ Aligned:  This is my video!
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0001.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" this is George .
# ✨ Aligned:  This is joy!
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0009.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" George loves stories .
# ✨ Aligned:  George Vastoy
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0018.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: she said nicely +".
# ✨ Aligned:  She said nice.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0029.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: CHILDNAME .
# ✨ Aligned:  K -Run.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0044.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: show it to me .
# ✨ Aligned:  Go to me!
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0041.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: play something .
# ✨ Aligned:  Why something?
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0011.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" when the wibrary start his story about jungle anino George could not wait any wonger .
# ✨ Aligned:  When the library started to story about jungle,... George could not wait any longer.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0024.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: is it raining ?
# ✨ Aligned:  Is it raining?
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0030.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" he wuun ↫ag↫against a shelf to rest .
# ✨ Aligned:  He would be against a shelf to rest.
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0029.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" he saw uh more uh could carry .
# ✨ Aligned:  lets start with a ghost chariot
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0007.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" was reading out loud .
# ✨ Aligned:  3D out, wow!
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient2_0028.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: good .
# ✨ Aligned:  Good!
#
# 🎧 Processing: /rds/general/user/ak8224/home/emoji_project/data/ASD/final/preprocessed/patient3_0035.wav
# /rds/general/user/ak8224/home/miniforge3/envs/emojivoice/lib/python3.10/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 📖 Original: +" and it moved .
# ✨ Aligned:  And boots
#
# ✅ Alignment complete! You can now use metadata_aligned.csv for training.
